# %%
from qiskit.quantum_info import Statevector, DensityMatrix
from numpy import sqrt
import numpy as np

v = Statevector([1,0])
v.draw("bloch")

# %%
r = DensityMatrix([[3/4, 0],[0, 1/4]])
r.draw("bloch")
